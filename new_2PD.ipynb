# %%
import pandas as pd
from pandas.plotting import scatter_matrix
import numpy as np
import matplotlib
# %matplotlib inline
import seaborn as sns
import missingno as msno
import shap
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split, StratifiedKFold, cross_val_score
from sklearn.svm import SVC
from sklearn.neighbors import KNeighborsClassifier
from sklearn.preprocessing import StandardScaler
from sklearn.pipeline import Pipeline
from sklearn.metrics import accuracy_score
from sklearn.metrics import classification_report

# %% [markdown]
# ## 데이터 전처리

# %%
df_raw = pd.read_csv('E:\\2-project\\2023_7th_kwcs.csv', encoding='cp949')

df_raw.info()
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_22428\3963318036.py:1: DtypeWarning: Columns (10,13,44,46,274,290,346,390) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_raw = pd.read_csv('E:\\2-project\\2023_7th_kwcs.csv', encoding='cp949')
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50195 entries, 0 to 50194
# Columns: 439 entries, id to hm_08_rel_t
# dtypes: float64(6), int64(199), object(234)
# memory usage: 168.1+ MB

# %%
df = df_raw

# %% [markdown]
# ### 데이터 필터링

# %%
# estat 2:임금근로자

print(df['estat'].value_counts())
# Out:
# estat
# 2    30073
# 1    15994
# 3     4024
# 4      104
# Name: count, dtype: int64

# %%
df = df[df['estat'] == 2]
df['estat'].value_counts()
# Out:
# estat
# 2    30073
# Name: count, dtype: int64
